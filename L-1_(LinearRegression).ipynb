# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area(sq ft)")
plt.ylabel('price(US$)')
plt.scatter(df.area,df.price, color = 'red', marker = '+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']].values,df.price)
# Out:
# LinearRegression()

# %%
reg.predict(np.array([[4000]]))
# Out:
# array([723767.12328767])

# %%
reg.predict(np.array([[10000]]))
# Out:
# array([1538493.15068493])

# %%
fd = pd.read_csv('canada_per_capita_income.csv')
fd.head(4)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248

# %%
plt.xlabel('year')
plt.ylabel('PCI (US$)')
plt.scatter(fd.year,fd['per capita income (US$)'],color='lightBlue', marker='*')

# %%
peg = linear_model.LinearRegression()
peg.fit(fd[['year']].values, fd[['per capita income (US$)']])
# Out:
# LinearRegression()

# %%
peg.predict(np.array([[2020]]))
# Out:
# array([[41288.69409442]])
